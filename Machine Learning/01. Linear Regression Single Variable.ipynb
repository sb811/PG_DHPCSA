# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv(r"D:\PGD - HPCSA\Machine Learning\Datasets\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area in SQ.FT')
plt.ylabel('Price is $')
plt.scatter(df.area, df.price, color='r', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000]])
# Out:
# c:\Users\exam\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
plt.xlabel('Area in SQ.FT')
plt.ylabel('Price is $')
plt.scatter(df.area, df.price, color='r', marker='+')
plt.plot(df.area, reg.predict(df[['area']]), color='b')
